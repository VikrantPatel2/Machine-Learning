# %% [markdown]
# Data types are a classification of data which tell the complier or interpreter how the programmer intends to use the tab.

# %%
### Integer Example 
age =35
type(age)
# Out:
# int

# %%
## floating point data type
weight=98.2
type(weight)
# Out:
# float

# %%
## string datatype
name='Vikrant'
print(name)
print(type(name))
# Out:
# Vikrant
# <class 'str'>

# %%
## boolean Datatype

type(True)
# Out:
# bool

# %%
a=10
b=10
type(a==b)
# Out:
# bool
