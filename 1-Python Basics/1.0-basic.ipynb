# %%
## Python is a case sensitive Language

name='Vikrant'
Name='Patel'

print(name)
print(Name)
# Out:
# Vikrant
# Patel

# %%
## Indentation- to define blocksof code

age =35
if age>30:
    print("You are an adult of age :",age)
# Out:
# You are an adult of age : 35

# %%
print("Hello World")
# Out:
# Hello World

# %%
## Line Continuation--  use of the backslash to continue a statement to the next line
total=1+2+3+5+6+\
4+56+8
print(total)
# Out:
# 85

# %%
### Multiple statement as single line

a=5;w=5;y=6
print(a+w+y)
# Out:
# 16

# %%
## Type inference

type(total)
variable=10
print(type(variable))
variable='Vikrant'
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>
