# %% [markdown]
# Variablees are fundamental elements in programming used to store data that can be referenced and manipulated in a program.

# %%
## Declaring and Assigning Variables

age =20
height =6.3
name='Vikrant'
is_student=True

print(age)
print(name)
print(height)
print(is_student)
# Out:
# 20
# Vikrant
# 6.3
# True

# %%
## Naming Convection
'''
Variable names should be descriptive
they must start with a letter or an '_' and contains letter, numbers and underscores
variable names are case senstitive
'''

##valid variable name

firt_name='Vikrant'
last_name='Patel'

# %%
### Understanding Variable Types
## Python is dynamically types , type of a variable at runtime
age=25
height=6.3
name='Patel'
is_student=True

print(type(name))
# Out:
# <class 'str'>

# %%
## Type Checking and conversion
type(height)
# Out:
# float

# %%
age=25
print(type(age))

age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
height=6.3
height_int=int(height)
print(height_int)
print(type(height_int))
# Out:
# 6
# <class 'int'>

# %%
### Dynamic Typing
var=10
print(var,type(var))

var="Hello"
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>

# %%
### input
age=int(input("Enter the age"))
print(age)
# Out:
# 20
