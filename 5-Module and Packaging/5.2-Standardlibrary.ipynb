# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
## random

import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 3
# banana

# %%
## File and Directory Access
import os 
print(os.getcwd())
# Out:
# c:\Users\vikra\OneDrive\Pictures\Desktop\Code\5-Module and Packaging

# %%
os.mkdir('test_dir')

# %%
### high level operations on files and collection of files

import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Serialization
import json
data={'name':'Jack','age':25}

json_str=json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Jack", "age": 25}
# <class 'str'>
# {'name': 'Jack', 'age': 25}
# <class 'dict'>

# %%
##Csv

import csv
with open('example.csv',mode='w',newline='') as file:
   writer= csv.writer(file)
   writer.writerow(['name','age'])
   writer.writerow(['Jack',29])

with open('example.csv',mode='r')as file:
   reader=csv.reader(file)
   for row in reader:
      print(row)
# Out:
# ['name', 'age']
# ['Jack', '29']

# %%
## datetime
from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-04-11 02:13:18.978995
# 2026-04-10 02:13:18.978995

# %%
### time

import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1775853856.4057722
# 1775853858.4060907

# %%
## regular expression

import re

pattern='\d+'
text='There are 2123 apples'
match=re.search(pattern,text)
print(match.group())
# Out:
# 2123
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\vikra\AppData\Local\Temp\ipykernel_31632\2921012842.py:5: SyntaxWarning: invalid escape sequence '\d'
#   pattern='\d+'
