# %% [markdown]
# ## Sets
# Sets are a built-in data type in Python used to store collections of unique items. THey are unordered meaning that the elements do not follow a specific order, and they do not allow duplicate elements. Sets are useful for membership tests eliminating duplicate entries, and performing mathematical set operations like union, intersection difference, and symmetric difference.

# %%
## create a set

my_set={1,2,3,4,5,5,4,5}
print(my_set)
print(type(my_set))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
## Basic set Operation

##Addition and removing elements

my_set.add(7)
print(my_set)
# Out:
# {1, 2, 4, 5, 7}

# %%
my_set.remove(4)
print(my_set)
# Out:
# {1, 2, 5, 7}

# %%
my_set.discard(10)
print(my_set)
# Out:
# {1, 2, 5, 7}

# %%
##Pop Method
removed_element=my_set.pop()
print(removed_element)
print(my_set)
# Out:
# 1
# {2, 5, 7}

# %%
## clear all the elements
my_set.clear()
print(my_set)
# Out:
# set()

# %%
## Set Memebership set
my_set={1,2,3,4,5,5,4,5}
print(3 in my_set)
print(10 in my_set)
# Out:
# True
# False

# %%
## Mathematical Operation
set1={1,2,3,4,5,6}
set2={4,5,6,7,8,9} 

##union
union_set=set1.union(set2)
print(union_set)

## Intersection 
intersection_set=set1.intersection(set2)
print(intersection_set)

set1.intersection_update(set2)  
print(set1)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}
# {4, 5, 6}
# {4, 5, 6}

# %%
set1={1,2,3,4,5,6}
set2={4,5,6,7,8,9} 

## difference
print(set1.difference(set2))
# Out:
# {1, 2, 3}

# %%
### symmeteric Difference
set1.symmetric_difference(set2)
# Out:
# {1, 2, 3, 7, 8, 9}

# %%
### sets Method
set1={1,2,3,4,5}
set2={3,4,5}

## is subset
print(set1.issubset(set2))

## is superset
print(set1.issuperset(set2))
# Out:
# False
# True

# %%
lst=[1,2,2,3,4,4,5]

set(lst)
# Out:
# {1, 2, 3, 4, 5}

# %%
### Counting Unqiue words in text

text="In this tutorial we  are disussing about sets"

words=text.split()
## convert list of words to set to get unique words

unique_words=set(words)
print(unique_words)
# Out:
# {'are', 'sets', 'we', 'In', 'this', 'tutorial', 'about', 'disussing'}
